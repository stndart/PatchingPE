# %% [markdown]
# # Paths

# %%
good_p = "../incremental_patch/good.csv"
bad1_p = "../incremental_patch/bad1.csv"

# %% [markdown]
# # Diff

# %%
import pandas as pd
a = pd.read_csv(good_p, usecols=[2])
b = pd.read_csv(bad1_p, usecols=[2])
for i, (x, y) in enumerate(zip(a, b)):
    if x != y:
        print(i, x, y)
        break

# %%
# Out:
# (106890, 1)
